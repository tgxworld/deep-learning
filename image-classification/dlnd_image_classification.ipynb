# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/cifar/cifar-10-python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 11
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 11:
# Image - Min Value: 4 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 3 Name: cat

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x / 255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
dict = {}
for i in range(0, 10):
    dict[i] = np.zeros(10)
    dict[i][i] = 1

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    output = []
    
    for i in x:
        output.append(dict[i])

    return np.array(output)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="x", shape=[None, image_shape[0], image_shape[1], image_shape[2]])


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="y", shape=[None, n_classes])


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    input_depth = x_tensor.get_shape().as_list()[3]
    
    weights = tf.Variable(tf.truncated_normal(
        [
            conv_ksize[0], 
            conv_ksize[1], 
            input_depth, 
            conv_num_outputs
        ],
        0.0,
        0.01
    ))
    
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    strides = (1, conv_strides[0], conv_strides[1], 1)
    
    conv_output = tf.nn.conv2d(x_tensor, weights, strides, 'SAME')
    conv_output = tf.nn.bias_add(conv_output, bias)
    conv_output = tf.nn.relu(conv_output)
    
    
    pool_ksize = (1, pool_ksize[0], pool_ksize[1], 1)
    pool_strides = (1, pool_strides[0], pool_strides[1], 1)
    
    return tf.nn.max_pool(conv_output, pool_ksize, pool_strides, 'SAME') 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    
    flatten_image_size = 1
    
    for i in shape:
        if i != None:
            flatten_image_size *= i
    
    return tf.reshape(x_tensor, (-1, flatten_image_size))
 

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    weights = tf.Variable(tf.truncated_normal((shape[1], num_outputs)))
    bias = tf.Variable(tf.zeros(num_outputs))
    output = tf.add(tf.matmul(x_tensor, weights), bias)
    return tf.nn.relu(output)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    weights = tf.Variable(tf.truncated_normal((shape[1], num_outputs)))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor, weights), bias)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides) 
    x = conv2d_maxpool(x, 16, [3, 3], [1, 1], [2, 2], [2, 2])
    x = conv2d_maxpool(x, 32, [3, 3], [1, 1], [2, 2], [2, 2])
    tf.nn.dropout(x, keep_prob)
    x = conv2d_maxpool(x, 78, [3, 3], [1, 1], [2, 2], [2, 2])
    tf.nn.dropout(x, keep_prob)
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    x = fully_conn(x, 64)
    tf.nn.dropout(x, keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    x = output(x, 10)
    
    
    # TODO: return output
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={keep_prob: keep_probability, x: feature_batch, y: label_batch})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    training_cost = session.run(cost, feed_dict={keep_prob: 1.0, x: feature_batch, y: label_batch})
    validation_accuracy = session.run(accuracy, feed_dict={keep_prob: 1.0, x: valid_features, y: valid_labels})
    
    print('\nTrainging cost at {}'.format(training_cost))
    print('Validation accuracy at {}'.format(validation_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 1000
keep_probability = 0.3

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:
# Trainging cost at 2.239762306213379
# Validation accuracy at 0.164000004529953
# Epoch  2, CIFAR-10 Batch 1:
# Trainging cost at 2.1361310482025146
# Validation accuracy at 0.2061999887228012
# Epoch  3, CIFAR-10 Batch 1:
# Trainging cost at 2.0694222450256348
# Validation accuracy at 0.23160001635551453
# Epoch  4, CIFAR-10 Batch 1:
# Trainging cost at 2.0002100467681885
# Validation accuracy at 0.26919999718666077
# Epoch  5, CIFAR-10 Batch 1:
# Trainging cost at 1.920340657234192
# Validation accuracy at 0.30799999833106995
# Epoch  6, CIFAR-10 Batch 1:
# Trainging cost at 1.876993179321289
# Validation accuracy at 0.3349999785423279
# Epoch  7, CIFAR-10 Batch 1:
# Trainging cost at 1.7856109142303467
# Validation accuracy at 0.35940003395080566
# Epoch  8, CIFAR-10 Batch 1:
# Trainging cost at 1.7486541271209717
# Validation accuracy at 0.368399977684021
# Epoch  9, CIFAR-10 Batch 1:
# Trainging cost at 1.706018328666687
# Validation accuracy at 0.3805999755859375
# Epoch 10, CIFAR-10 Batch 1:
# Trainging cost at 1.6472489833831787
# Validation accuracy at 0.4017999470233917
# Epoch 11, CIFAR-10 Batch 1:
# Trainging cost at 1.622243881225586
# Validation accuracy at 0.4225999712944031
# Epoch 12, CIFAR-10 Batch 1:
# Trainging cost at 1.5793756246566772
# Validation accuracy at 0.431799978017807
# Epoch 13, CIFAR-10 Batch 1:
# Trainging cost at 1.5588617324829102
# Validation accuracy at 0.42719995975494385
# Epoch 14, CIFAR-10 Batch 1:
# Trainging cost at 1.5207778215408325
# Validation accuracy at 0.4395999610424042
# Epoch 15, CIFAR-10 Batch 1:
# Trainging cost at 1.5059281587600708
# Validation accuracy at 0.4421999752521515
# Epoch 16, CIFAR-10 Batch 1:
# Trainging cost at 1.4816176891326904
# Validation accuracy at 0.4445999562740326
# Epoch 17, CIFAR-10 Batch 1:
# Trainging cost at 1.4591883420944214
# Validation accuracy at 0.44839999079704285
# Epoch 18, CIFAR-10 Batch 1:
# Trainging cost at 1.4447226524353027
# Validation accuracy at 0.4509999752044678
# Epoch 19, CIFAR-10 Batch 1:
# Trainging cost at 1.4152956008911133
# Validation accuracy at 0.46279993653297424
# Epoch 20, CIFAR-10 Batch 1:
# Trainging cost at 1.393724799156189
# Validation accuracy at 0.4739999771118164
# Epoch 21, CIFAR-10 Batch 1:
# Trainging cost at 1.3776533603668213
# Validation accuracy at 0.47679996490478516
# Epoch 22, CIFAR-10 Batch 1:
# Trainging cost at 1.3645849227905273
# Validation accuracy at 0.48079997301101685
# Epoch 23, CIFAR-10 Batch 1:
# Trainging cost at 1.3544737100601196
# Validation accuracy at 0.48639994859695435
# Epoch 24, CIFAR-10 Batch 1:
# Trainging cost at 1.3251506090164185
# Validation accuracy at 0.4907999634742737
# Epoch 25, CIFAR-10 Batch 1:
# Trainging cost at 1.3294763565063477
# Validation accuracy at 0.49459993839263916
# Epoch 26, CIFAR-10 Batch 1:
# Trainging cost at 1.329052448272705
# Validation accuracy at 0.48979994654655457
# Epoch 27, CIFAR-10 Batch 1:
# Trainging cost at 1.3490382432937622
# Validation accuracy at 0.4809999465942383
# Epoch 28, CIFAR-10 Batch 1:
# Trainging cost at 1.3482111692428589
# Validation accuracy at 0.48319992423057556
# Epoch 29, CIFAR-10 Batch 1:
# Trainging cost at 1.2787597179412842
# Validation accuracy at 0.495199978351593
# Epoch 30, CIFAR-10 Batch 1:
# Trainging cost at 1.266719937324524
# Validation accuracy at 0.4939999580383301
# Epoch 31, CIFAR-10 Batch 1:
# Trainging cost at 1.258510708808899
# Validation accuracy at 0.4949999451637268
# Epoch 32, CIFAR-10 Batch 1:
# Trainging cost at 1.2483500242233276
# Validation accuracy at 0.4973999559879303
# Epoch 33, CIFAR-10 Batch 1:
# Trainging cost at 1.2329742908477783
# Validation accuracy at 0.5055999755859375
# Epoch 34, CIFAR-10 Batch 1:
# Trainging cost at 1.211879014968872
# Validation accuracy at 0.512199878692627
# Epoch 35, CIFAR-10 Batch 1:
# Trainging cost at 1.194862961769104
# Validation accuracy at 0.5181999802589417
# Epoch 36, CIFAR-10 Batch 1:
# Trainging cost at 1.186543583869934
# Validation accuracy at 0.517799973487854
# Epoch 37, CIFAR-10 Batch 1:
# Trainging cost at 1.18028724193573
# Validation accuracy at 0.5195999145507812
# Epoch 38, CIFAR-10 Batch 1:
# Trainging cost at 1.1774258613586426
# Validation accuracy at 0.5193999409675598
# Epoch 39, CIFAR-10 Batch 1:
# Trainging cost at 1.168052077293396
# Validation accuracy at 0.5245999693870544
# Epoch 40, CIFAR-10 Batch 1:
# Trainging cost at 1.1751431226730347
# Validation accuracy at 0.5219999551773071
# Epoch 41, CIFAR-10 Batch 1:
# Trainging cost at 1.1763731241226196
# Validation accuracy at 0.5237998962402344
# Epoch 42, CIFAR-10 Batch 1:
# Trainging cost at 1.1407549381256104
# Validation accuracy at 0.5251999497413635
# Epoch 43, CIFAR-10 Batch 1:
# Trainging cost at 1.1788854598999023
# Validation accuracy at 0.5179999470710754
# Epoch 44, CIFAR-10 Batch 1:
# Trainging cost at 1.1223520040512085
# Validation accuracy at 0.5309999585151672
# Epoch 45, CIFAR-10 Batch 1:
# Trainging cost at 1.1094095706939697
# Validation accuracy at 0.5309999585151672
# Epoch 46, CIFAR-10 Batch 1:
# Trainging cost at 1.1115174293518066
# Validation accuracy at 0.5287999510765076
# Epoch 47, CIFAR-10 Batch 1:
# Trainging cost at 1.1020936965942383
# Validation accuracy at 0.5295999050140381
# Epoch 48, CIFAR-10 Batch 1:
# Trainging cost at 1.0816327333450317
# Validation accuracy at 0.533799946308136
# Epoch 49, CIFAR-10 Batch 1:
# Trainging cost at 1.0627057552337646
# Validation accuracy at 0.5353999733924866
# Epoch 50, CIFAR-10 Batch 1:
# Trainging cost at 1.0522427558898926
# Validation accuracy at 0.5383999347686768
# Epoch 51, CIFAR-10 Batch 1:
# Trainging cost at 1.0420145988464355
# Validation accuracy at 0.5405998826026917
# Epoch 52, CIFAR-10 Batch 1:
# Trainging cost at 1.0346046686172485
# Validation accuracy at 0.5383999347686768
# Epoch 53, CIFAR-10 Batch 1:
# Trainging cost at 1.0299633741378784
# Validation accuracy at 0.5385999083518982
# Epoch 54, CIFAR-10 Batch 1:
# Trainging cost at 1.0329540967941284
# Validation accuracy at 0.531999945640564
# Epoch 55, CIFAR-10 Batch 1:
# Trainging cost at 1.0346715450286865
# Validation accuracy at 0.5329999327659607
# Epoch 56, CIFAR-10 Batch 1:
# Trainging cost at 1.0351084470748901
# Validation accuracy at 0.5351999402046204
# Epoch 57, CIFAR-10 Batch 1:
# Trainging cost at 1.0135066509246826
# Validation accuracy at 0.5407999753952026
# Epoch 58, CIFAR-10 Batch 1:
# Trainging cost at 0.9972436428070068
# Validation accuracy at 0.5455999374389648
# Epoch 59, CIFAR-10 Batch 1:
# Trainging cost at 0.9998544454574585
# Validation accuracy at 0.5415999293327332
# Epoch 60, CIFAR-10 Batch 1:
# Trainging cost at 0.9927635788917542
# Validation accuracy at 0.5413999557495117
# Epoch 61, CIFAR-10 Batch 1:
# Trainging cost at 0.9904594421386719
# Validation accuracy at 0.542199969291687
# Epoch 62, CIFAR-10 Batch 1:
# Trainging cost at 0.9914926290512085
# Validation accuracy at 0.5329999327659607
# Epoch 63, CIFAR-10 Batch 1:
# Trainging cost at 1.0446898937225342
# Validation accuracy at 0.507599949836731
# Epoch 64, CIFAR-10 Batch 1:
# Trainging cost at 0.9759026765823364
# Validation accuracy at 0.5345999002456665
# Epoch 65, CIFAR-10 Batch 1:
# Trainging cost at 0.9493719339370728
# Validation accuracy at 0.5523999333381653
# Epoch 66, CIFAR-10 Batch 1:
# Trainging cost at 0.9544833898544312
# Validation accuracy at 0.54339998960495
# Epoch 67, CIFAR-10 Batch 1:
# Trainging cost at 0.9481895565986633
# Validation accuracy at 0.542199969291687
# Epoch 68, CIFAR-10 Batch 1:
# Trainging cost at 0.9485944509506226
# Validation accuracy at 0.5403999090194702
# Epoch 69, CIFAR-10 Batch 1:
# Trainging cost at 0.940160870552063
# Validation accuracy at 0.5425999760627747
# Epoch 70, CIFAR-10 Batch 1:
# Trainging cost at 0.9414936304092407
# Validation accuracy at 0.5383999347686768
# Epoch 71, CIFAR-10 Batch 1:
# Trainging cost at 0.9389629364013672
# Validation accuracy at 0.5407999157905579
# Epoch 72, CIFAR-10 Batch 1:
# Trainging cost at 0.9317636489868164
# Validation accuracy at 0.5447999835014343
# Epoch 73, CIFAR-10 Batch 1:
# Trainging cost at 0.9250035285949707
# Validation accuracy at 0.5445999503135681
# Epoch 74, CIFAR-10 Batch 1:
# Trainging cost at 0.9174830913543701
# Validation accuracy at 0.5461999177932739
# Epoch 75, CIFAR-10 Batch 1:
# Trainging cost at 0.9041421413421631
# Validation accuracy at 0.546799898147583
# Epoch 76, CIFAR-10 Batch 1:
# Trainging cost at 0.8920924663543701
# Validation accuracy at 0.5539999008178711
# Epoch 77, CIFAR-10 Batch 1:
# Trainging cost at 0.8884801268577576
# Validation accuracy at 0.5535998940467834
# Epoch 78, CIFAR-10 Batch 1:
# Trainging cost at 0.8863633871078491
# Validation accuracy at 0.5537999272346497
# Epoch 79, CIFAR-10 Batch 1:
# Trainging cost at 0.8850245475769043
# Validation accuracy at 0.5501999258995056
# Epoch 80, CIFAR-10 Batch 1:
# Trainging cost at 0.8885509967803955
# Validation accuracy at 0.5499999523162842
# Epoch 81, CIFAR-10 Batch 1:
# Trainging cost at 0.8835070133209229
# Validation accuracy at 0.5505999326705933
# Epoch 82, CIFAR-10 Batch 1:
# Trainging cost at 0.8636190891265869
# Validation accuracy at 0.5531998872756958
# Epoch 83, CIFAR-10 Batch 1:
# Trainging cost at 0.8539654016494751
# Validation accuracy at 0.556399941444397
# Epoch 84, CIFAR-10 Batch 1:
# Trainging cost at 0.8457662463188171
# Validation accuracy at 0.5551999807357788
# Epoch 85, CIFAR-10 Batch 1:
# Trainging cost at 0.8362044095993042
# Validation accuracy at 0.5585998892784119
# Epoch 86, CIFAR-10 Batch 1:
# Trainging cost at 0.8463413715362549
# Validation accuracy at 0.5549998879432678
# Epoch 87, CIFAR-10 Batch 1:
# Trainging cost at 0.8542333245277405
# Validation accuracy at 0.5567999482154846
# Epoch 88, CIFAR-10 Batch 1:
# Trainging cost at 0.8185067772865295
# Validation accuracy at 0.5585999488830566
# Epoch 89, CIFAR-10 Batch 1:
# Trainging cost at 0.8207151889801025
# Validation accuracy at 0.554599940776825
# Epoch 90, CIFAR-10 Batch 1:
# Trainging cost at 0.8163354992866516
# Validation accuracy at 0.5547999143600464
# Epoch 91, CIFAR-10 Batch 1:
# Trainging cost at 0.8174213171005249
# Validation accuracy at 0.5523999333381653
# Epoch 92, CIFAR-10 Batch 1:
# Trainging cost at 0.8084350228309631
# Validation accuracy at 0.5539999604225159
# Epoch 93, CIFAR-10 Batch 1:
# Trainging cost at 0.8038848042488098
# Validation accuracy at 0.5465999245643616
# Epoch 94, CIFAR-10 Batch 1:
# Trainging cost at 0.8377130627632141
# Validation accuracy at 0.5357999801635742
# Epoch 95, CIFAR-10 Batch 1:
# Trainging cost at 0.8554120659828186
# Validation accuracy at 0.5345999598503113
# Epoch 96, CIFAR-10 Batch 1:
# Trainging cost at 0.7960237860679626
# Validation accuracy at 0.5529999136924744
# Epoch 97, CIFAR-10 Batch 1:
# Trainging cost at 0.7960050702095032
# Validation accuracy at 0.5525999069213867
# Epoch 98, CIFAR-10 Batch 1:
# Trainging cost at 0.7779749631881714
# Validation accuracy at 0.5535999536514282
# Epoch 99, CIFAR-10 Batch 1:
# Trainging cost at 0.7854876518249512
# Validation accuracy at 0.5469999313354492
# Epoch 100, CIFAR-10 Batch 1:
# Trainging cost at 0.7784448266029358
# Validation accuracy at 0.5481999516487122

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:
# Trainging cost at 2.285386800765991
# Validation accuracy at 0.15879997611045837
# Epoch  1, CIFAR-10 Batch 2:
# Trainging cost at 2.2008635997772217
# Validation accuracy at 0.19460001587867737
# Epoch  1, CIFAR-10 Batch 3:
# Trainging cost at 2.111743688583374
# Validation accuracy at 0.22699999809265137
# Epoch  1, CIFAR-10 Batch 4:
# Trainging cost at 2.0368292331695557
# Validation accuracy at 0.2515999972820282
# Epoch  1, CIFAR-10 Batch 5:
# Trainging cost at 2.006781816482544
# Validation accuracy at 0.26339998841285706
# Epoch  2, CIFAR-10 Batch 1:
# Trainging cost at 2.0105061531066895
# Validation accuracy at 0.2709999978542328
# Epoch  2, CIFAR-10 Batch 2:
# Trainging cost at 1.9531028270721436
# Validation accuracy at 0.2993999719619751
# Epoch  2, CIFAR-10 Batch 3:
# Trainging cost at 1.9105465412139893
# Validation accuracy at 0.3089999854564667
# Epoch  2, CIFAR-10 Batch 4:
# Trainging cost at 1.8670302629470825
# Validation accuracy at 0.3157999813556671
# Epoch  2, CIFAR-10 Batch 5:
# Trainging cost at 1.862007737159729
# Validation accuracy at 0.3353999853134155
# Epoch  3, CIFAR-10 Batch 1:
# Trainging cost at 1.8486175537109375
# Validation accuracy at 0.35099998116493225
# Epoch  3, CIFAR-10 Batch 2:
# Trainging cost at 1.8038443326950073
# Validation accuracy at 0.3643999695777893
# Epoch  3, CIFAR-10 Batch 3:
# Trainging cost at 1.7549506425857544
# Validation accuracy at 0.37119999527931213
# Epoch  3, CIFAR-10 Batch 4:
# Trainging cost at 1.7241188287734985
# Validation accuracy at 0.38120001554489136
# Epoch  3, CIFAR-10 Batch 5:
# Trainging cost at 1.743163824081421
# Validation accuracy at 0.3855999708175659
# Epoch  4, CIFAR-10 Batch 1:
# Trainging cost at 1.749796748161316
# Validation accuracy at 0.3813999593257904
# Epoch  4, CIFAR-10 Batch 2:
# Trainging cost at 1.6790025234222412
# Validation accuracy at 0.39399999380111694
# Epoch  4, CIFAR-10 Batch 3:
# Trainging cost at 1.6414520740509033
# Validation accuracy at 0.4016000032424927
# Epoch  4, CIFAR-10 Batch 4:
# Trainging cost at 1.6430943012237549
# Validation accuracy at 0.4127999246120453
# Epoch  4, CIFAR-10 Batch 5:
# Trainging cost at 1.6382838487625122
# Validation accuracy at 0.42399993538856506
# Epoch  5, CIFAR-10 Batch 1:
# Trainging cost at 1.6400102376937866
# Validation accuracy at 0.4161999821662903
# Epoch  5, CIFAR-10 Batch 2:
# Trainging cost at 1.602772831916809
# Validation accuracy at 0.41839998960494995
# Epoch  5, CIFAR-10 Batch 3:
# Trainging cost at 1.5595905780792236
# Validation accuracy at 0.4368000030517578
# Epoch  5, CIFAR-10 Batch 4:
# Trainging cost at 1.5711907148361206
# Validation accuracy at 0.4383999705314636
# Epoch  5, CIFAR-10 Batch 5:
# Trainging cost at 1.5730335712432861
# Validation accuracy at 0.44199997186660767
# Epoch  6, CIFAR-10 Batch 1:
# Trainging cost at 1.5776448249816895
# Validation accuracy at 0.43919992446899414
# Epoch  6, CIFAR-10 Batch 2:
# Trainging cost at 1.5533294677734375
# Validation accuracy at 0.44020000100135803
# Epoch  6, CIFAR-10 Batch 3:
# Trainging cost at 1.5061345100402832
# Validation accuracy at 0.45399996638298035
# Epoch  6, CIFAR-10 Batch 4:
# Trainging cost at 1.5151699781417847
# Validation accuracy at 0.4541999399662018
# Epoch  6, CIFAR-10 Batch 5:
# Trainging cost at 1.518707513809204
# Validation accuracy at 0.45579996705055237
# Epoch  7, CIFAR-10 Batch 1:
# Trainging cost at 1.5238040685653687
# Validation accuracy at 0.45899996161460876
# Epoch  7, CIFAR-10 Batch 2:
# Trainging cost at 1.5179722309112549
# Validation accuracy at 0.4501999616622925
# Epoch  7, CIFAR-10 Batch 3:
# Trainging cost at 1.4689518213272095
# Validation accuracy at 0.46699997782707214
# Epoch  7, CIFAR-10 Batch 4:
# Trainging cost at 1.4669060707092285
# Validation accuracy at 0.4691999852657318
# Epoch  7, CIFAR-10 Batch 5:
# Trainging cost at 1.4733375310897827
# Validation accuracy at 0.4719999432563782
# Epoch  8, CIFAR-10 Batch 1:
# Trainging cost at 1.4766656160354614
# Validation accuracy at 0.47099998593330383
# Epoch  8, CIFAR-10 Batch 2:
# Trainging cost at 1.4832708835601807
# Validation accuracy at 0.4603999853134155
# Epoch  8, CIFAR-10 Batch 3:
# Trainging cost at 1.4280877113342285
# Validation accuracy at 0.48059993982315063
# Epoch  8, CIFAR-10 Batch 4:
# Trainging cost at 1.423256516456604
# Validation accuracy at 0.4827999472618103
# Epoch  8, CIFAR-10 Batch 5:
# Trainging cost at 1.437638759613037
# Validation accuracy at 0.48239994049072266
# Epoch  9, CIFAR-10 Batch 1:
# Trainging cost at 1.431056022644043
# Validation accuracy at 0.4861999452114105
# Epoch  9, CIFAR-10 Batch 2:
# Trainging cost at 1.4524712562561035
# Validation accuracy at 0.4715999364852905
# Epoch  9, CIFAR-10 Batch 3:
# Trainging cost at 1.399785041809082
# Validation accuracy at 0.48579996824264526
# Epoch  9, CIFAR-10 Batch 4:
# Trainging cost at 1.3899716138839722
# Validation accuracy at 0.48899999260902405
# Epoch  9, CIFAR-10 Batch 5:
# Trainging cost at 1.4002090692520142
# Validation accuracy at 0.494799941778183
# Epoch 10, CIFAR-10 Batch 1:
# Trainging cost at 1.4076365232467651
# Validation accuracy at 0.4939999282360077
# Epoch 10, CIFAR-10 Batch 2:
# Trainging cost at 1.3991087675094604
# Validation accuracy at 0.49859994649887085
# Epoch 10, CIFAR-10 Batch 3:
# Trainging cost at 1.373363971710205
# Validation accuracy at 0.4943999648094177
# Epoch 10, CIFAR-10 Batch 4:
# Trainging cost at 1.3681060075759888
# Validation accuracy at 0.49679994583129883
# Epoch 10, CIFAR-10 Batch 5:
# Trainging cost at 1.3682727813720703
# Validation accuracy at 0.5043999552726746
# Epoch 11, CIFAR-10 Batch 1:
# Trainging cost at 1.3659926652908325
# Validation accuracy at 0.502799928188324
# Epoch 11, CIFAR-10 Batch 2:
# Trainging cost at 1.3686004877090454
# Validation accuracy at 0.5063999891281128
# Epoch 11, CIFAR-10 Batch 3:
# Trainging cost at 1.3393828868865967
# Validation accuracy at 0.5071999430656433
# Epoch 11, CIFAR-10 Batch 4:
# Trainging cost at 1.3266427516937256
# Validation accuracy at 0.5071999430656433
# Epoch 11, CIFAR-10 Batch 5:
# Trainging cost at 1.3485407829284668
# Validation accuracy at 0.5105999112129211
# Epoch 12, CIFAR-10 Batch 1:
# Trainging cost at 1.3420907258987427
# Validation accuracy at 0.5101999640464783
# Epoch 12, CIFAR-10 Batch 2:
# Trainging cost at 1.3651577234268188
# Validation accuracy at 0.5001999139785767
# Epoch 12, CIFAR-10 Batch 3:
# Trainging cost at 1.3303874731063843
# Validation accuracy at 0.5031999349594116
# Epoch 12, CIFAR-10 Batch 4:
# Trainging cost at 1.3125473260879517
# Validation accuracy at 0.5105999112129211
# Epoch 12, CIFAR-10 Batch 5:
# Trainging cost at 1.332900047302246
# Validation accuracy at 0.5131999254226685
# Epoch 13, CIFAR-10 Batch 1:
# Trainging cost at 1.3078587055206299
# Validation accuracy at 0.5205999612808228
# Epoch 13, CIFAR-10 Batch 2:
# Trainging cost at 1.328324556350708
# Validation accuracy at 0.5173999667167664
# Epoch 13, CIFAR-10 Batch 3:
# Trainging cost at 1.3023912906646729
# Validation accuracy at 0.5119999051094055
# Epoch 13, CIFAR-10 Batch 4:
# Trainging cost at 1.2782145738601685
# Validation accuracy at 0.5191999673843384
# Epoch 13, CIFAR-10 Batch 5:
# Trainging cost at 1.3085664510726929
# Validation accuracy at 0.5249999165534973
# Epoch 14, CIFAR-10 Batch 1:
# Trainging cost at 1.2965277433395386
# Validation accuracy at 0.5255998969078064
# Epoch 14, CIFAR-10 Batch 2:
# Trainging cost at 1.3279845714569092
# Validation accuracy at 0.512999951839447
# Epoch 14, CIFAR-10 Batch 3:
# Trainging cost at 1.3001725673675537
# Validation accuracy at 0.5103999376296997
# Epoch 14, CIFAR-10 Batch 4:
# Trainging cost at 1.2691466808319092
# Validation accuracy at 0.5275999903678894
# Epoch 14, CIFAR-10 Batch 5:
# Trainging cost at 1.3000773191452026
# Validation accuracy at 0.5277999043464661
# Epoch 15, CIFAR-10 Batch 1:
# Trainging cost at 1.2722043991088867
# Validation accuracy at 0.5311999320983887
# Epoch 15, CIFAR-10 Batch 2:
# Trainging cost at 1.2995150089263916
# Validation accuracy at 0.525399923324585
# Epoch 15, CIFAR-10 Batch 3:
# Trainging cost at 1.2761693000793457
# Validation accuracy at 0.5211999416351318
# Epoch 15, CIFAR-10 Batch 4:
# Trainging cost at 1.2459819316864014
# Validation accuracy at 0.5288000106811523
# Epoch 15, CIFAR-10 Batch 5:
# Trainging cost at 1.2812544107437134
# Validation accuracy at 0.5361999273300171
# Epoch 16, CIFAR-10 Batch 1:
# Trainging cost at 1.2632977962493896
# Validation accuracy at 0.5347999334335327
# Epoch 16, CIFAR-10 Batch 2:
# Trainging cost at 1.2830305099487305
# Validation accuracy at 0.530799925327301
# Epoch 16, CIFAR-10 Batch 3:
# Trainging cost at 1.271425724029541
# Validation accuracy at 0.5225999355316162
# Epoch 16, CIFAR-10 Batch 4:
# Trainging cost at 1.2337665557861328
# Validation accuracy at 0.533799946308136
# Epoch 16, CIFAR-10 Batch 5:
# Trainging cost at 1.272117018699646
# Validation accuracy at 0.5375999808311462
# Epoch 17, CIFAR-10 Batch 1:
# Trainging cost at 1.2427175045013428
# Validation accuracy at 0.5411999225616455
# Epoch 17, CIFAR-10 Batch 2:
# Trainging cost at 1.2686831951141357
# Validation accuracy at 0.5363999605178833
# Epoch 17, CIFAR-10 Batch 3:
# Trainging cost at 1.2531894445419312
# Validation accuracy at 0.5311999320983887
# Epoch 17, CIFAR-10 Batch 4:
# Trainging cost at 1.21724271774292
# Validation accuracy at 0.5385999083518982
# Epoch 17, CIFAR-10 Batch 5:
# Trainging cost at 1.2548093795776367
# Validation accuracy at 0.5423998832702637
# Epoch 18, CIFAR-10 Batch 1:
# Trainging cost at 1.2318251132965088
# Validation accuracy at 0.5453999638557434
# Epoch 18, CIFAR-10 Batch 2:
# Trainging cost at 1.2606397867202759
# Validation accuracy at 0.5425999760627747
# Epoch 18, CIFAR-10 Batch 3:
# Trainging cost at 1.2475782632827759
# Validation accuracy at 0.5339999198913574
# Epoch 18, CIFAR-10 Batch 4:
# Trainging cost at 1.2048914432525635
# Validation accuracy at 0.5443999171257019
# Epoch 18, CIFAR-10 Batch 5:
# Trainging cost at 1.241804599761963
# Validation accuracy at 0.5443999767303467
# Epoch 19, CIFAR-10 Batch 1:
# Trainging cost at 1.2219055891036987
# Validation accuracy at 0.5477999448776245
# Epoch 19, CIFAR-10 Batch 2:
# Trainging cost at 1.248117446899414
# Validation accuracy at 0.5463999509811401
# Epoch 19, CIFAR-10 Batch 3:
# Trainging cost at 1.237627625465393
# Validation accuracy at 0.5331999063491821
# Epoch 19, CIFAR-10 Batch 4:
# Trainging cost at 1.1930773258209229
# Validation accuracy at 0.5499999523162842
# Epoch 19, CIFAR-10 Batch 5:
# Trainging cost at 1.2305669784545898
# Validation accuracy at 0.5499999523162842
# Epoch 20, CIFAR-10 Batch 1:
# Trainging cost at 1.2082860469818115
# Validation accuracy at 0.553399920463562
# Epoch 20, CIFAR-10 Batch 2:
# Trainging cost at 1.2413413524627686
# Validation accuracy at 0.547999918460846
# Epoch 20, CIFAR-10 Batch 3:
# Trainging cost at 1.2239571809768677
# Validation accuracy at 0.5353999733924866
# Epoch 20, CIFAR-10 Batch 4:
# Trainging cost at 1.182896614074707
# Validation accuracy at 0.5553999543190002
# Epoch 20, CIFAR-10 Batch 5:
# Trainging cost at 1.219521403312683
# Validation accuracy at 0.5525999665260315
# Epoch 21, CIFAR-10 Batch 1:
# Trainging cost at 1.1976326704025269
# Validation accuracy at 0.5565999150276184
# Epoch 21, CIFAR-10 Batch 2:
# Trainging cost at 1.2303009033203125
# Validation accuracy at 0.5531999468803406
# Epoch 21, CIFAR-10 Batch 3:
# Trainging cost at 1.211852788925171
# Validation accuracy at 0.5389999151229858
# Epoch 21, CIFAR-10 Batch 4:
# Trainging cost at 1.1737048625946045
# Validation accuracy at 0.5583999752998352
# Epoch 21, CIFAR-10 Batch 5:
# Trainging cost at 1.20668625831604
# Validation accuracy at 0.5595999360084534
# Epoch 22, CIFAR-10 Batch 1:
# Trainging cost at 1.183179259300232
# Validation accuracy at 0.5587999224662781
# Epoch 22, CIFAR-10 Batch 2:
# Trainging cost at 1.2225626707077026
# Validation accuracy at 0.5565999150276184
# Epoch 22, CIFAR-10 Batch 3:
# Trainging cost at 1.1950371265411377
# Validation accuracy at 0.5475999116897583
# Epoch 22, CIFAR-10 Batch 4:
# Trainging cost at 1.1642885208129883
# Validation accuracy at 0.5629999041557312
# Epoch 22, CIFAR-10 Batch 5:
# Trainging cost at 1.1939088106155396
# Validation accuracy at 0.5597999691963196
# Epoch 23, CIFAR-10 Batch 1:
# Trainging cost at 1.1722320318222046
# Validation accuracy at 0.5611999034881592
# Epoch 23, CIFAR-10 Batch 2:
# Trainging cost at 1.2149513959884644
# Validation accuracy at 0.5573999285697937
# Epoch 23, CIFAR-10 Batch 3:
# Trainging cost at 1.1864845752716064
# Validation accuracy at 0.5519999265670776
# Epoch 23, CIFAR-10 Batch 4:
# Trainging cost at 1.1548599004745483
# Validation accuracy at 0.5681999325752258
# Epoch 23, CIFAR-10 Batch 5:
# Trainging cost at 1.1851246356964111
# Validation accuracy at 0.5609999299049377
# Epoch 24, CIFAR-10 Batch 1:
# Trainging cost at 1.160383701324463
# Validation accuracy at 0.5633999109268188
# Epoch 24, CIFAR-10 Batch 2:
# Trainging cost at 1.205507516860962
# Validation accuracy at 0.5601999163627625
# Epoch 24, CIFAR-10 Batch 3:
# Trainging cost at 1.1792469024658203
# Validation accuracy at 0.5547999143600464
# Epoch 24, CIFAR-10 Batch 4:
# Trainging cost at 1.1462501287460327
# Validation accuracy at 0.5715999007225037
# Epoch 24, CIFAR-10 Batch 5:
# Trainging cost at 1.1758270263671875
# Validation accuracy at 0.5637999773025513
# Epoch 25, CIFAR-10 Batch 1:
# Trainging cost at 1.1488608121871948
# Validation accuracy at 0.5649999380111694
# Epoch 25, CIFAR-10 Batch 2:
# Trainging cost at 1.193211317062378
# Validation accuracy at 0.5639998912811279
# Epoch 25, CIFAR-10 Batch 3:
# Trainging cost at 1.1649055480957031
# Validation accuracy at 0.5601999163627625
# Epoch 25, CIFAR-10 Batch 4:
# Trainging cost at 1.138488531112671
# Validation accuracy at 0.5733999609947205
# Epoch 25, CIFAR-10 Batch 5:
# Trainging cost at 1.1649211645126343
# Validation accuracy at 0.5641999244689941
# Epoch 26, CIFAR-10 Batch 1:
# Trainging cost at 1.1396079063415527
# Validation accuracy at 0.5671999454498291
# Epoch 26, CIFAR-10 Batch 2:
# Trainging cost at 1.1897740364074707
# Validation accuracy at 0.5629999041557312
# Epoch 26, CIFAR-10 Batch 3:
# Trainging cost at 1.162536859512329
# Validation accuracy at 0.5609999299049377
# Epoch 26, CIFAR-10 Batch 4:
# Trainging cost at 1.1284736394882202
# Validation accuracy at 0.5753999352455139
# Epoch 26, CIFAR-10 Batch 5:
# Trainging cost at 1.1574426889419556
# Validation accuracy at 0.5659999847412109
# Epoch 27, CIFAR-10 Batch 1:
# Trainging cost at 1.132124423980713
# Validation accuracy at 0.5691999197006226
# Epoch 27, CIFAR-10 Batch 2:
# Trainging cost at 1.174849033355713
# Validation accuracy at 0.5645999908447266
# Epoch 27, CIFAR-10 Batch 3:
# Trainging cost at 1.16463041305542
# Validation accuracy at 0.5579999685287476
# Epoch 27, CIFAR-10 Batch 4:
# Trainging cost at 1.1223502159118652
# Validation accuracy at 0.5781999826431274
# Epoch 27, CIFAR-10 Batch 5:
# Trainging cost at 1.1524200439453125
# Validation accuracy at 0.5713999271392822
# Epoch 28, CIFAR-10 Batch 1:
# Trainging cost at 1.1263700723648071
# Validation accuracy at 0.5673999190330505
# Epoch 28, CIFAR-10 Batch 2:
# Trainging cost at 1.1580836772918701
# Validation accuracy at 0.5715999603271484
# Epoch 28, CIFAR-10 Batch 3:
# Trainging cost at 1.153464436531067
# Validation accuracy at 0.5619999170303345
# Epoch 28, CIFAR-10 Batch 4:
# Trainging cost at 1.1159380674362183
# Validation accuracy at 0.5803999304771423
# Epoch 28, CIFAR-10 Batch 5:
# Trainging cost at 1.1455302238464355
# Validation accuracy at 0.5740000009536743
# Epoch 29, CIFAR-10 Batch 1:
# Trainging cost at 1.119018316268921
# Validation accuracy at 0.5707998871803284
# Epoch 29, CIFAR-10 Batch 2:
# Trainging cost at 1.1500276327133179
# Validation accuracy at 0.5753999948501587
# Epoch 29, CIFAR-10 Batch 3:
# Trainging cost at 1.1459711790084839
# Validation accuracy at 0.5625998973846436
# Epoch 29, CIFAR-10 Batch 4:
# Trainging cost at 1.1113594770431519
# Validation accuracy at 0.5835999250411987
# Epoch 29, CIFAR-10 Batch 5:
# Trainging cost at 1.1377002000808716
# Validation accuracy at 0.5753999352455139
# Epoch 30, CIFAR-10 Batch 1:
# Trainging cost at 1.1110049486160278
# Validation accuracy at 0.5763998627662659
# Epoch 30, CIFAR-10 Batch 2:
# Trainging cost at 1.1419076919555664
# Validation accuracy at 0.5791999101638794
# Epoch 30, CIFAR-10 Batch 3:
# Trainging cost at 1.1379493474960327
# Validation accuracy at 0.5665999054908752
# Epoch 30, CIFAR-10 Batch 4:
# Trainging cost at 1.1044269800186157
# Validation accuracy at 0.5855998992919922
# Epoch 30, CIFAR-10 Batch 5:
# Trainging cost at 1.1331528425216675
# Validation accuracy at 0.5799999237060547
# Epoch 31, CIFAR-10 Batch 1:
# Trainging cost at 1.103708267211914
# Validation accuracy at 0.5783998966217041
# Epoch 31, CIFAR-10 Batch 2:
# Trainging cost at 1.1332515478134155
# Validation accuracy at 0.5797999501228333
# Epoch 31, CIFAR-10 Batch 3:
# Trainging cost at 1.1265523433685303
# Validation accuracy at 0.5695999264717102
# Epoch 31, CIFAR-10 Batch 4:
# Trainging cost at 1.0997883081436157
# Validation accuracy at 0.5891999006271362
# Epoch 31, CIFAR-10 Batch 5:
# Trainging cost at 1.1246180534362793
# Validation accuracy at 0.5817999243736267
# Epoch 32, CIFAR-10 Batch 1:
# Trainging cost at 1.0982959270477295
# Validation accuracy at 0.5813999176025391
# Epoch 32, CIFAR-10 Batch 2:
# Trainging cost at 1.1295489072799683
# Validation accuracy at 0.5833998918533325
# Epoch 32, CIFAR-10 Batch 3:
# Trainging cost at 1.121714472770691
# Validation accuracy at 0.5717998743057251
# Epoch 32, CIFAR-10 Batch 4:
# Trainging cost at 1.095015287399292
# Validation accuracy at 0.5917999744415283
# Epoch 32, CIFAR-10 Batch 5:
# Trainging cost at 1.1164783239364624
# Validation accuracy at 0.5835999250411987
# Epoch 33, CIFAR-10 Batch 1:
# Trainging cost at 1.0925761461257935
# Validation accuracy at 0.5843998789787292
# Epoch 33, CIFAR-10 Batch 2:
# Trainging cost at 1.1253383159637451
# Validation accuracy at 0.5821999311447144
# Epoch 33, CIFAR-10 Batch 3:
# Trainging cost at 1.1229376792907715
# Validation accuracy at 0.5707998871803284
# Epoch 33, CIFAR-10 Batch 4:
# Trainging cost at 1.0948512554168701
# Validation accuracy at 0.5925998687744141
# Epoch 33, CIFAR-10 Batch 5:
# Trainging cost at 1.108076810836792
# Validation accuracy at 0.5869999527931213
# Epoch 34, CIFAR-10 Batch 1:
# Trainging cost at 1.0894581079483032
# Validation accuracy at 0.5847998857498169
# Epoch 34, CIFAR-10 Batch 2:
# Trainging cost at 1.1179256439208984
# Validation accuracy at 0.5849999189376831
# Epoch 34, CIFAR-10 Batch 3:
# Trainging cost at 1.118575930595398
# Validation accuracy at 0.5723999738693237
# Epoch 34, CIFAR-10 Batch 4:
# Trainging cost at 1.0945459604263306
# Validation accuracy at 0.5913999080657959
# Epoch 34, CIFAR-10 Batch 5:
# Trainging cost at 1.1012170314788818
# Validation accuracy at 0.5885999202728271
# Epoch 35, CIFAR-10 Batch 1:
# Trainging cost at 1.0815507173538208
# Validation accuracy at 0.5869999527931213
# Epoch 35, CIFAR-10 Batch 2:
# Trainging cost at 1.104611873626709
# Validation accuracy at 0.5917999148368835
# Epoch 35, CIFAR-10 Batch 3:
# Trainging cost at 1.10903000831604
# Validation accuracy at 0.5739999413490295
# Epoch 35, CIFAR-10 Batch 4:
# Trainging cost at 1.0882537364959717
# Validation accuracy at 0.5911999344825745
# Epoch 35, CIFAR-10 Batch 5:
# Trainging cost at 1.091484546661377
# Validation accuracy at 0.590999960899353
# Epoch 36, CIFAR-10 Batch 1:
# Trainging cost at 1.0766602754592896
# Validation accuracy at 0.5907999277114868
# Epoch 36, CIFAR-10 Batch 2:
# Trainging cost at 1.0967220067977905
# Validation accuracy at 0.5929998755455017
# Epoch 36, CIFAR-10 Batch 3:
# Trainging cost at 1.0935006141662598
# Validation accuracy at 0.5811998844146729
# Epoch 36, CIFAR-10 Batch 4:
# Trainging cost at 1.0802913904190063
# Validation accuracy at 0.5945998430252075
# Epoch 36, CIFAR-10 Batch 5:
# Trainging cost at 1.0821268558502197
# Validation accuracy at 0.5949998497962952
# Epoch 37, CIFAR-10 Batch 1:
# Trainging cost at 1.070277452468872
# Validation accuracy at 0.5925999283790588
# Epoch 37, CIFAR-10 Batch 2:
# Trainging cost at 1.093290090560913
# Validation accuracy at 0.5927999019622803
# Epoch 37, CIFAR-10 Batch 3:
# Trainging cost at 1.0883150100708008
# Validation accuracy at 0.5849999189376831
# Epoch 37, CIFAR-10 Batch 4:
# Trainging cost at 1.0740278959274292
# Validation accuracy at 0.5949998497962952
# Epoch 37, CIFAR-10 Batch 5:
# Trainging cost at 1.0753345489501953
# Validation accuracy at 0.5965999364852905
# Epoch 38, CIFAR-10 Batch 1:
# Trainging cost at 1.0662391185760498
# Validation accuracy at 0.5951998829841614
# Epoch 38, CIFAR-10 Batch 2:
# Trainging cost at 1.0903291702270508
# Validation accuracy at 0.5935999155044556
# Epoch 38, CIFAR-10 Batch 3:
# Trainging cost at 1.085344910621643
# Validation accuracy at 0.5831998586654663
# Epoch 38, CIFAR-10 Batch 4:
# Trainging cost at 1.0686414241790771
# Validation accuracy at 0.5981998443603516
# Epoch 38, CIFAR-10 Batch 5:
# Trainging cost at 1.0700232982635498
# Validation accuracy at 0.5979999303817749
# Epoch 39, CIFAR-10 Batch 1:
# Trainging cost at 1.0592063665390015
# Validation accuracy at 0.597399890422821
# Epoch 39, CIFAR-10 Batch 2:
# Trainging cost at 1.0845305919647217
# Validation accuracy at 0.5945999622344971
# Epoch 39, CIFAR-10 Batch 3:
# Trainging cost at 1.0777626037597656
# Validation accuracy at 0.5857999324798584
# Epoch 39, CIFAR-10 Batch 4:
# Trainging cost at 1.064496397972107
# Validation accuracy at 0.5987999439239502
# Epoch 39, CIFAR-10 Batch 5:
# Trainging cost at 1.0636054277420044
# Validation accuracy at 0.600399911403656
# Epoch 40, CIFAR-10 Batch 1:
# Trainging cost at 1.0557787418365479
# Validation accuracy at 0.5975998640060425
# Epoch 40, CIFAR-10 Batch 2:
# Trainging cost at 1.0829893350601196
# Validation accuracy at 0.5933998823165894
# Epoch 40, CIFAR-10 Batch 3:
# Trainging cost at 1.0673894882202148
# Validation accuracy at 0.5897998809814453
# Epoch 40, CIFAR-10 Batch 4:
# Trainging cost at 1.0623228549957275
# Validation accuracy at 0.5987999439239502
# Epoch 40, CIFAR-10 Batch 5:
# Trainging cost at 1.056462049484253
# Validation accuracy at 0.6003999710083008
# Epoch 41, CIFAR-10 Batch 1:
# Trainging cost at 1.0483100414276123
# Validation accuracy at 0.5979999303817749
# Epoch 41, CIFAR-10 Batch 2:
# Trainging cost at 1.077256441116333
# Validation accuracy at 0.5933998823165894
# Epoch 41, CIFAR-10 Batch 3:
# Trainging cost at 1.0578255653381348
# Validation accuracy at 0.5931999087333679
# Epoch 41, CIFAR-10 Batch 4:
# Trainging cost at 1.0590686798095703
# Validation accuracy at 0.5993999242782593
# Epoch 41, CIFAR-10 Batch 5:
# Trainging cost at 1.0485944747924805
# Validation accuracy at 0.603399932384491
# Epoch 42, CIFAR-10 Batch 1:
# Trainging cost at 1.0423856973648071
# Validation accuracy at 0.6005998849868774
# Epoch 42, CIFAR-10 Batch 2:
# Trainging cost at 1.0730116367340088
# Validation accuracy at 0.5947999358177185
# Epoch 42, CIFAR-10 Batch 3:
# Trainging cost at 1.0476258993148804
# Validation accuracy at 0.5965999364852905
# Epoch 42, CIFAR-10 Batch 4:
# Trainging cost at 1.056638479232788
# Validation accuracy at 0.5965998768806458
# Epoch 42, CIFAR-10 Batch 5:
# Trainging cost at 1.0415822267532349
# Validation accuracy at 0.6043999195098877
# Epoch 43, CIFAR-10 Batch 1:
# Trainging cost at 1.038705825805664
# Validation accuracy at 0.6027998924255371
# Epoch 43, CIFAR-10 Batch 2:
# Trainging cost at 1.0689945220947266
# Validation accuracy at 0.5965999364852905
# Epoch 43, CIFAR-10 Batch 3:
# Trainging cost at 1.0420364141464233
# Validation accuracy at 0.5977998971939087
# Epoch 43, CIFAR-10 Batch 4:
# Trainging cost at 1.0522940158843994
# Validation accuracy at 0.6001999378204346
# Epoch 43, CIFAR-10 Batch 5:
# Trainging cost at 1.035163164138794
# Validation accuracy at 0.6061998605728149
# Epoch 44, CIFAR-10 Batch 1:
# Trainging cost at 1.0318491458892822
# Validation accuracy at 0.6045998930931091
# Epoch 44, CIFAR-10 Batch 2:
# Trainging cost at 1.0663748979568481
# Validation accuracy at 0.598599910736084
# Epoch 44, CIFAR-10 Batch 3:
# Trainging cost at 1.032317876815796
# Validation accuracy at 0.6029999256134033
# Epoch 44, CIFAR-10 Batch 4:
# Trainging cost at 1.0472038984298706
# Validation accuracy at 0.6014000177383423
# Epoch 44, CIFAR-10 Batch 5:
# Trainging cost at 1.0292924642562866
# Validation accuracy at 0.6067999601364136
# Epoch 45, CIFAR-10 Batch 1:
# Trainging cost at 1.0296638011932373
# Validation accuracy at 0.6049998998641968
# Epoch 45, CIFAR-10 Batch 2:
# Trainging cost at 1.064716100692749
# Validation accuracy at 0.5977999567985535
# Epoch 45, CIFAR-10 Batch 3:
# Trainging cost at 1.0263636112213135
# Validation accuracy at 0.6043999195098877
# Epoch 45, CIFAR-10 Batch 4:
# Trainging cost at 1.0444976091384888
# Validation accuracy at 0.6005998849868774
# Epoch 45, CIFAR-10 Batch 5:
# Trainging cost at 1.0219427347183228
# Validation accuracy at 0.6107999086380005
# Epoch 46, CIFAR-10 Batch 1:
# Trainging cost at 1.026059627532959
# Validation accuracy at 0.6069998741149902
# Epoch 46, CIFAR-10 Batch 2:
# Trainging cost at 1.0621263980865479
# Validation accuracy at 0.6005998849868774
# Epoch 46, CIFAR-10 Batch 3:
# Trainging cost at 1.0187952518463135
# Validation accuracy at 0.605199933052063
# Epoch 46, CIFAR-10 Batch 4:
# Trainging cost at 1.040761947631836
# Validation accuracy at 0.601599931716919
# Epoch 46, CIFAR-10 Batch 5:
# Trainging cost at 1.017380714416504
# Validation accuracy at 0.6103999614715576
# Epoch 47, CIFAR-10 Batch 1:
# Trainging cost at 1.0203121900558472
# Validation accuracy at 0.6107999086380005
# Epoch 47, CIFAR-10 Batch 2:
# Trainging cost at 1.0571255683898926
# Validation accuracy at 0.5999999046325684
# Epoch 47, CIFAR-10 Batch 3:
# Trainging cost at 1.0132136344909668
# Validation accuracy at 0.6065999269485474
# Epoch 47, CIFAR-10 Batch 4:
# Trainging cost at 1.0347545146942139
# Validation accuracy at 0.6041999459266663
# Epoch 47, CIFAR-10 Batch 5:
# Trainging cost at 1.0148440599441528
# Validation accuracy at 0.6109999418258667
# Epoch 48, CIFAR-10 Batch 1:
# Trainging cost at 1.017674446105957
# Validation accuracy at 0.6103999018669128
# Epoch 48, CIFAR-10 Batch 2:
# Trainging cost at 1.0507303476333618
# Validation accuracy at 0.6055998802185059
# Epoch 48, CIFAR-10 Batch 3:
# Trainging cost at 1.0074007511138916
# Validation accuracy at 0.6087998747825623
# Epoch 48, CIFAR-10 Batch 4:
# Trainging cost at 1.0299230813980103
# Validation accuracy at 0.6055999398231506
# Epoch 48, CIFAR-10 Batch 5:
# Trainging cost at 1.0104267597198486
# Validation accuracy at 0.6125999093055725
# Epoch 49, CIFAR-10 Batch 1:
# Trainging cost at 1.0143301486968994
# Validation accuracy at 0.6095999479293823
# Epoch 49, CIFAR-10 Batch 2:
# Trainging cost at 1.0485968589782715
# Validation accuracy at 0.6085999011993408
# Epoch 49, CIFAR-10 Batch 3:
# Trainging cost at 1.002800703048706
# Validation accuracy at 0.6099998950958252
# Epoch 49, CIFAR-10 Batch 4:
# Trainging cost at 1.0278525352478027
# Validation accuracy at 0.6073999404907227
# Epoch 49, CIFAR-10 Batch 5:
# Trainging cost at 1.0066306591033936
# Validation accuracy at 0.6145999431610107
# Epoch 50, CIFAR-10 Batch 1:
# Trainging cost at 1.0124727487564087
# Validation accuracy at 0.6103999614715576
# Epoch 50, CIFAR-10 Batch 2:
# Trainging cost at 1.0419726371765137
# Validation accuracy at 0.6107999086380005
# Epoch 50, CIFAR-10 Batch 3:
# Trainging cost at 1.0000572204589844
# Validation accuracy at 0.6091999411582947
# Epoch 50, CIFAR-10 Batch 4:
# Trainging cost at 1.020916223526001
# Validation accuracy at 0.6103999614715576
# Epoch 50, CIFAR-10 Batch 5:
# Trainging cost at 1.003995418548584
# Validation accuracy at 0.6157998442649841
# Epoch 51, CIFAR-10 Batch 1:
# Trainging cost at 1.0202943086624146
# Validation accuracy at 0.6101999282836914
# Epoch 51, CIFAR-10 Batch 2:
# Trainging cost at 1.0297703742980957
# Validation accuracy at 0.6175999045372009
# Epoch 51, CIFAR-10 Batch 3:
# Trainging cost at 1.0131229162216187
# Validation accuracy at 0.6009998917579651
# Epoch 51, CIFAR-10 Batch 4:
# Trainging cost at 1.0104515552520752
# Validation accuracy at 0.6165999174118042
# Epoch 51, CIFAR-10 Batch 5:
# Trainging cost at 0.9969468712806702
# Validation accuracy at 0.6173999309539795
# Epoch 52, CIFAR-10 Batch 1:
# Trainging cost at 1.0281671285629272
# Validation accuracy at 0.6087998747825623
# Epoch 52, CIFAR-10 Batch 2:
# Trainging cost at 1.0413490533828735
# Validation accuracy at 0.6149998903274536
# Epoch 52, CIFAR-10 Batch 3:
# Trainging cost at 1.005660057067871
# Validation accuracy at 0.6093999147415161
# Epoch 52, CIFAR-10 Batch 4:
# Trainging cost at 1.0197772979736328
# Validation accuracy at 0.6125998497009277
# Epoch 52, CIFAR-10 Batch 5:
# Trainging cost at 0.9902564287185669
# Validation accuracy at 0.6171998977661133
# Epoch 53, CIFAR-10 Batch 1:
# Trainging cost at 1.0063644647598267
# Validation accuracy at 0.6141998767852783
# Epoch 53, CIFAR-10 Batch 2:
# Trainging cost at 1.0342910289764404
# Validation accuracy at 0.6175999045372009
# Epoch 53, CIFAR-10 Batch 3:
# Trainging cost at 0.9857249855995178
# Validation accuracy at 0.6177998781204224
# Epoch 53, CIFAR-10 Batch 4:
# Trainging cost at 1.0041321516036987
# Validation accuracy at 0.6183999180793762
# Epoch 53, CIFAR-10 Batch 5:
# Trainging cost at 0.9777429699897766
# Validation accuracy at 0.6169999241828918
# Epoch 54, CIFAR-10 Batch 1:
# Trainging cost at 0.9980236291885376
# Validation accuracy at 0.6191999316215515
# Epoch 54, CIFAR-10 Batch 2:
# Trainging cost at 1.0188772678375244
# Validation accuracy at 0.6189998388290405
# Epoch 54, CIFAR-10 Batch 3:
# Trainging cost at 0.9860985279083252
# Validation accuracy at 0.6119999289512634
# Epoch 54, CIFAR-10 Batch 4:
# Trainging cost at 1.001632571220398
# Validation accuracy at 0.619999885559082
# Epoch 54, CIFAR-10 Batch 5:
# Trainging cost at 0.9745674133300781
# Validation accuracy at 0.6199999451637268
# Epoch 55, CIFAR-10 Batch 1:
# Trainging cost at 0.9925436973571777
# Validation accuracy at 0.6185998916625977
# Epoch 55, CIFAR-10 Batch 2:
# Trainging cost at 1.0181859731674194
# Validation accuracy at 0.6213999390602112
# Epoch 55, CIFAR-10 Batch 3:
# Trainging cost at 0.9805029034614563
# Validation accuracy at 0.6139999032020569
# Epoch 55, CIFAR-10 Batch 4:
# Trainging cost at 0.9997833371162415
# Validation accuracy at 0.6213999390602112
# Epoch 55, CIFAR-10 Batch 5:
# Trainging cost at 0.9693546295166016
# Validation accuracy at 0.621199905872345
# Epoch 56, CIFAR-10 Batch 1:
# Trainging cost at 0.9942677021026611
# Validation accuracy at 0.6189999580383301
# Epoch 56, CIFAR-10 Batch 2:
# Trainging cost at 1.0161128044128418
# Validation accuracy at 0.6237999200820923
# Epoch 56, CIFAR-10 Batch 3:
# Trainging cost at 0.9765998721122742
# Validation accuracy at 0.6153998374938965
# Epoch 56, CIFAR-10 Batch 4:
# Trainging cost at 0.996577262878418
# Validation accuracy at 0.6233999729156494
# Epoch 56, CIFAR-10 Batch 5:
# Trainging cost at 0.9637913107872009
# Validation accuracy at 0.6225998997688293
# Epoch 57, CIFAR-10 Batch 1:
# Trainging cost at 0.990879237651825
# Validation accuracy at 0.6219999194145203
# Epoch 57, CIFAR-10 Batch 2:
# Trainging cost at 1.0103839635849
# Validation accuracy at 0.6261999011039734
# Epoch 57, CIFAR-10 Batch 3:
# Trainging cost at 0.9719546437263489
# Validation accuracy at 0.6159999370574951
# Epoch 57, CIFAR-10 Batch 4:
# Trainging cost at 0.9936440587043762
# Validation accuracy at 0.6231999397277832
# Epoch 57, CIFAR-10 Batch 5:
# Trainging cost at 0.9586675763130188
# Validation accuracy at 0.6221998929977417
# Epoch 58, CIFAR-10 Batch 1:
# Trainging cost at 0.9873261451721191
# Validation accuracy at 0.6229998469352722
# Epoch 58, CIFAR-10 Batch 2:
# Trainging cost at 1.0075092315673828
# Validation accuracy at 0.6285998821258545
# Epoch 58, CIFAR-10 Batch 3:
# Trainging cost at 0.9709092974662781
# Validation accuracy at 0.6147999167442322
# Epoch 58, CIFAR-10 Batch 4:
# Trainging cost at 0.9922053813934326
# Validation accuracy at 0.6229999661445618
# Epoch 58, CIFAR-10 Batch 5:
# Trainging cost at 0.9545475244522095
# Validation accuracy at 0.6231999397277832
# Epoch 59, CIFAR-10 Batch 1:
# Trainging cost at 0.9853150844573975
# Validation accuracy at 0.6251998543739319
# Epoch 59, CIFAR-10 Batch 2:
# Trainging cost at 1.0062665939331055
# Validation accuracy at 0.6285998821258545
# Epoch 59, CIFAR-10 Batch 3:
# Trainging cost at 0.9670078158378601
# Validation accuracy at 0.6147999167442322
# Epoch 59, CIFAR-10 Batch 4:
# Trainging cost at 0.9874798655509949
# Validation accuracy at 0.6243999004364014
# Epoch 59, CIFAR-10 Batch 5:
# Trainging cost at 0.9507207870483398
# Validation accuracy at 0.6243999004364014
# Epoch 60, CIFAR-10 Batch 1:
# Trainging cost at 0.9795655012130737
# Validation accuracy at 0.6257998943328857
# Epoch 60, CIFAR-10 Batch 2:
# Trainging cost at 1.0026968717575073
# Validation accuracy at 0.6313998699188232
# Epoch 60, CIFAR-10 Batch 3:
# Trainging cost at 0.9646667242050171
# Validation accuracy at 0.6155999302864075
# Epoch 60, CIFAR-10 Batch 4:
# Trainging cost at 0.9828329086303711
# Validation accuracy at 0.6257998943328857
# Epoch 60, CIFAR-10 Batch 5:
# Trainging cost at 0.9462504386901855
# Validation accuracy at 0.6291998624801636
# Epoch 61, CIFAR-10 Batch 1:
# Trainging cost at 0.9749754667282104
# Validation accuracy at 0.6257998943328857
# Epoch 61, CIFAR-10 Batch 2:
# Trainging cost at 1.000881314277649
# Validation accuracy at 0.630599856376648
# Epoch 61, CIFAR-10 Batch 3:
# Trainging cost at 0.9591291546821594
# Validation accuracy at 0.619399905204773
# Epoch 61, CIFAR-10 Batch 4:
# Trainging cost at 0.979617714881897
# Validation accuracy at 0.6255999207496643
# Epoch 61, CIFAR-10 Batch 5:
# Trainging cost at 0.9422262907028198
# Validation accuracy at 0.6299998760223389
# Epoch 62, CIFAR-10 Batch 1:
# Trainging cost at 0.9727129936218262
# Validation accuracy at 0.6251998543739319
# Epoch 62, CIFAR-10 Batch 2:
# Trainging cost at 0.9996221661567688
# Validation accuracy at 0.6309998631477356
# Epoch 62, CIFAR-10 Batch 3:
# Trainging cost at 0.9544263482093811
# Validation accuracy at 0.6223998665809631
# Epoch 62, CIFAR-10 Batch 4:
# Trainging cost at 0.9751164317131042
# Validation accuracy at 0.6257998943328857
# Epoch 62, CIFAR-10 Batch 5:
# Trainging cost at 0.937049925327301
# Validation accuracy at 0.6309999227523804
# Epoch 63, CIFAR-10 Batch 1:
# Trainging cost at 0.9689285755157471
# Validation accuracy at 0.6257998943328857
# Epoch 63, CIFAR-10 Batch 2:
# Trainging cost at 0.9960743188858032
# Validation accuracy at 0.6329998970031738
# Epoch 63, CIFAR-10 Batch 3:
# Trainging cost at 0.9481803774833679
# Validation accuracy at 0.6261999011039734
# Epoch 63, CIFAR-10 Batch 4:
# Trainging cost at 0.970880389213562
# Validation accuracy at 0.6267998814582825
# Epoch 63, CIFAR-10 Batch 5:
# Trainging cost at 0.9335702657699585
# Validation accuracy at 0.6327998638153076
# Epoch 64, CIFAR-10 Batch 1:
# Trainging cost at 0.9640942215919495
# Validation accuracy at 0.6283999085426331
# Epoch 64, CIFAR-10 Batch 2:
# Trainging cost at 0.9938402771949768
# Validation accuracy at 0.6315999031066895
# Epoch 64, CIFAR-10 Batch 3:
# Trainging cost at 0.9453356862068176
# Validation accuracy at 0.6259998679161072
# Epoch 64, CIFAR-10 Batch 4:
# Trainging cost at 0.9666948318481445
# Validation accuracy at 0.627599835395813
# Epoch 64, CIFAR-10 Batch 5:
# Trainging cost at 0.929489016532898
# Validation accuracy at 0.6355999708175659
# Epoch 65, CIFAR-10 Batch 1:
# Trainging cost at 0.9603161811828613
# Validation accuracy at 0.6281999349594116
# Epoch 65, CIFAR-10 Batch 2:
# Trainging cost at 0.9895550012588501
# Validation accuracy at 0.63239985704422
# Epoch 65, CIFAR-10 Batch 3:
# Trainging cost at 0.9416513442993164
# Validation accuracy at 0.6255999207496643
# Epoch 65, CIFAR-10 Batch 4:
# Trainging cost at 0.9614590406417847
# Validation accuracy at 0.6293998956680298
# Epoch 65, CIFAR-10 Batch 5:
# Trainging cost at 0.9244984984397888
# Validation accuracy at 0.6367998719215393
# Epoch 66, CIFAR-10 Batch 1:
# Trainging cost at 0.9542578458786011
# Validation accuracy at 0.6297999024391174
# Epoch 66, CIFAR-10 Batch 2:
# Trainging cost at 0.9865604639053345
# Validation accuracy at 0.6307999491691589
# Epoch 66, CIFAR-10 Batch 3:
# Trainging cost at 0.9374733567237854
# Validation accuracy at 0.6255998611450195
# Epoch 66, CIFAR-10 Batch 4:
# Trainging cost at 0.9591202139854431
# Validation accuracy at 0.6291999220848083
# Epoch 66, CIFAR-10 Batch 5:
# Trainging cost at 0.9223313331604004
# Validation accuracy at 0.6379998922348022
# Epoch 67, CIFAR-10 Batch 1:
# Trainging cost at 0.9504859447479248
# Validation accuracy at 0.6323999166488647
# Epoch 67, CIFAR-10 Batch 2:
# Trainging cost at 0.9836320281028748
# Validation accuracy at 0.6291999220848083
# Epoch 67, CIFAR-10 Batch 3:
# Trainging cost at 0.9356557130813599
# Validation accuracy at 0.6223999261856079
# Epoch 67, CIFAR-10 Batch 4:
# Trainging cost at 0.9562250375747681
# Validation accuracy at 0.6305999159812927
# Epoch 67, CIFAR-10 Batch 5:
# Trainging cost at 0.9187352061271667
# Validation accuracy at 0.6369999051094055
# Epoch 68, CIFAR-10 Batch 1:
# Trainging cost at 0.9468664526939392
# Validation accuracy at 0.6353998780250549
# Epoch 68, CIFAR-10 Batch 2:
# Trainging cost at 0.9814015030860901
# Validation accuracy at 0.6303999423980713
# Epoch 68, CIFAR-10 Batch 3:
# Trainging cost at 0.9358919262886047
# Validation accuracy at 0.6235999464988708
# Epoch 68, CIFAR-10 Batch 4:
# Trainging cost at 0.9517350196838379
# Validation accuracy at 0.6313998699188232
# Epoch 68, CIFAR-10 Batch 5:
# Trainging cost at 0.9163671731948853
# Validation accuracy at 0.6385998725891113
# Epoch 69, CIFAR-10 Batch 1:
# Trainging cost at 0.9431124925613403
# Validation accuracy at 0.637799859046936
# Epoch 69, CIFAR-10 Batch 2:
# Trainging cost at 0.9792928695678711
# Validation accuracy at 0.6327998638153076
# Epoch 69, CIFAR-10 Batch 3:
# Trainging cost at 0.9366819262504578
# Validation accuracy at 0.6243999004364014
# Epoch 69, CIFAR-10 Batch 4:
# Trainging cost at 0.9486198425292969
# Validation accuracy at 0.6317998766899109
# Epoch 69, CIFAR-10 Batch 5:
# Trainging cost at 0.9145375490188599
# Validation accuracy at 0.6363998651504517
# Epoch 70, CIFAR-10 Batch 1:
# Trainging cost at 0.9416709542274475
# Validation accuracy at 0.6363999247550964
# Epoch 70, CIFAR-10 Batch 2:
# Trainging cost at 0.9779977202415466
# Validation accuracy at 0.6317999362945557
# Epoch 70, CIFAR-10 Batch 3:
# Trainging cost at 0.9332306385040283
# Validation accuracy at 0.6251997947692871
# Epoch 70, CIFAR-10 Batch 4:
# Trainging cost at 0.9459593296051025
# Validation accuracy at 0.6319999098777771
# Epoch 70, CIFAR-10 Batch 5:
# Trainging cost at 0.9120920896530151
# Validation accuracy at 0.636199951171875
# Epoch 71, CIFAR-10 Batch 1:
# Trainging cost at 0.93928462266922
# Validation accuracy at 0.6373999118804932
# Epoch 71, CIFAR-10 Batch 2:
# Trainging cost at 0.973524808883667
# Validation accuracy at 0.6315999031066895
# Epoch 71, CIFAR-10 Batch 3:
# Trainging cost at 0.9305832982063293
# Validation accuracy at 0.6237999200820923
# Epoch 71, CIFAR-10 Batch 4:
# Trainging cost at 0.9436681270599365
# Validation accuracy at 0.6345999240875244
# Epoch 71, CIFAR-10 Batch 5:
# Trainging cost at 0.9075024127960205
# Validation accuracy at 0.6393999457359314
# Epoch 72, CIFAR-10 Batch 1:
# Trainging cost at 0.9353565573692322
# Validation accuracy at 0.6375998854637146
# Epoch 72, CIFAR-10 Batch 2:
# Trainging cost at 0.9693015813827515
# Validation accuracy at 0.6325998902320862
# Epoch 72, CIFAR-10 Batch 3:
# Trainging cost at 0.9249414801597595
# Validation accuracy at 0.625999927520752
# Epoch 72, CIFAR-10 Batch 4:
# Trainging cost at 0.9426831007003784
# Validation accuracy at 0.6349998712539673
# Epoch 72, CIFAR-10 Batch 5:
# Trainging cost at 0.9043976664543152
# Validation accuracy at 0.6415998935699463
# Epoch 73, CIFAR-10 Batch 1:
# Trainging cost at 0.9324958324432373
# Validation accuracy at 0.6391999125480652
# Epoch 73, CIFAR-10 Batch 2:
# Trainging cost at 0.967022180557251
# Validation accuracy at 0.6347999572753906
# Epoch 73, CIFAR-10 Batch 3:
# Trainging cost at 0.9188898801803589
# Validation accuracy at 0.6293998956680298
# Epoch 73, CIFAR-10 Batch 4:
# Trainging cost at 0.9405699968338013
# Validation accuracy at 0.6349998712539673
# Epoch 73, CIFAR-10 Batch 5:
# Trainging cost at 0.901666522026062
# Validation accuracy at 0.6421999335289001
# Epoch 74, CIFAR-10 Batch 1:
# Trainging cost at 0.9305930733680725
# Validation accuracy at 0.6391999125480652
# Epoch 74, CIFAR-10 Batch 2:
# Trainging cost at 0.9638786315917969
# Validation accuracy at 0.6333999037742615
# Epoch 74, CIFAR-10 Batch 3:
# Trainging cost at 0.9174421429634094
# Validation accuracy at 0.6303999423980713
# Epoch 74, CIFAR-10 Batch 4:
# Trainging cost at 0.9400933980941772
# Validation accuracy at 0.6349999308586121
# Epoch 74, CIFAR-10 Batch 5:
# Trainging cost at 0.9000877141952515
# Validation accuracy at 0.6423999667167664
# Epoch 75, CIFAR-10 Batch 1:
# Trainging cost at 0.9294171333312988
# Validation accuracy at 0.6395998597145081
# Epoch 75, CIFAR-10 Batch 2:
# Trainging cost at 0.9609806537628174
# Validation accuracy at 0.6371999382972717
# Epoch 75, CIFAR-10 Batch 3:
# Trainging cost at 0.9123575091362
# Validation accuracy at 0.6343998908996582
# Epoch 75, CIFAR-10 Batch 4:
# Trainging cost at 0.9376543760299683
# Validation accuracy at 0.636199951171875
# Epoch 75, CIFAR-10 Batch 5:
# Trainging cost at 0.8963283896446228
# Validation accuracy at 0.6427998542785645
# Epoch 76, CIFAR-10 Batch 1:
# Trainging cost at 0.9272100329399109
# Validation accuracy at 0.6399999260902405
# Epoch 76, CIFAR-10 Batch 2:
# Trainging cost at 0.9582345485687256
# Validation accuracy at 0.6377999186515808
# Epoch 76, CIFAR-10 Batch 3:
# Trainging cost at 0.9101496934890747
# Validation accuracy at 0.6361998915672302
# Epoch 76, CIFAR-10 Batch 4:
# Trainging cost at 0.9347706437110901
# Validation accuracy at 0.6357998847961426
# Epoch 76, CIFAR-10 Batch 5:
# Trainging cost at 0.8941344022750854
# Validation accuracy at 0.644399881362915
# Epoch 77, CIFAR-10 Batch 1:
# Trainging cost at 0.9260601997375488
# Validation accuracy at 0.6401998400688171
# Epoch 77, CIFAR-10 Batch 2:
# Trainging cost at 0.9553433656692505
# Validation accuracy at 0.6379998922348022
# Epoch 77, CIFAR-10 Batch 3:
# Trainging cost at 0.9088536500930786
# Validation accuracy at 0.6357998847961426
# Epoch 77, CIFAR-10 Batch 4:
# Trainging cost at 0.9316408038139343
# Validation accuracy at 0.6381998658180237
# Epoch 77, CIFAR-10 Batch 5:
# Trainging cost at 0.8918364644050598
# Validation accuracy at 0.6427999138832092
# Epoch 78, CIFAR-10 Batch 1:
# Trainging cost at 0.9246765375137329
# Validation accuracy at 0.6401999592781067
# Epoch 78, CIFAR-10 Batch 2:
# Trainging cost at 0.9535622000694275
# Validation accuracy at 0.6373999118804932
# Epoch 78, CIFAR-10 Batch 3:
# Trainging cost at 0.9064244031906128
# Validation accuracy at 0.6381998658180237
# Epoch 78, CIFAR-10 Batch 4:
# Trainging cost at 0.9296950101852417
# Validation accuracy at 0.6383998394012451
# Epoch 78, CIFAR-10 Batch 5:
# Trainging cost at 0.890101432800293
# Validation accuracy at 0.6439999341964722
# Epoch 79, CIFAR-10 Batch 1:
# Trainging cost at 0.9216228723526001
# Validation accuracy at 0.642599880695343
# Epoch 79, CIFAR-10 Batch 2:
# Trainging cost at 0.9504331350326538
# Validation accuracy at 0.6391998529434204
# Epoch 79, CIFAR-10 Batch 3:
# Trainging cost at 0.9010046124458313
# Validation accuracy at 0.638999879360199
# Epoch 79, CIFAR-10 Batch 4:
# Trainging cost at 0.9281083941459656
# Validation accuracy at 0.637199878692627
# Epoch 79, CIFAR-10 Batch 5:
# Trainging cost at 0.8877266645431519
# Validation accuracy at 0.6435998678207397
# Epoch 80, CIFAR-10 Batch 1:
# Trainging cost at 0.9212682247161865
# Validation accuracy at 0.640799880027771
# Epoch 80, CIFAR-10 Batch 2:
# Trainging cost at 0.947698712348938
# Validation accuracy at 0.6401998996734619
# Epoch 80, CIFAR-10 Batch 3:
# Trainging cost at 0.9001861810684204
# Validation accuracy at 0.6383998990058899
# Epoch 80, CIFAR-10 Batch 4:
# Trainging cost at 0.9260416626930237
# Validation accuracy at 0.6367999315261841
# Epoch 80, CIFAR-10 Batch 5:
# Trainging cost at 0.8862836956977844
# Validation accuracy at 0.6447998881340027
# Epoch 81, CIFAR-10 Batch 1:
# Trainging cost at 0.9222420454025269
# Validation accuracy at 0.6383998990058899
# Epoch 81, CIFAR-10 Batch 2:
# Trainging cost at 0.9436126351356506
# Validation accuracy at 0.640799880027771
# Epoch 81, CIFAR-10 Batch 3:
# Trainging cost at 0.8975646495819092
# Validation accuracy at 0.6385998725891113
# Epoch 81, CIFAR-10 Batch 4:
# Trainging cost at 0.9228999018669128
# Validation accuracy at 0.6395998597145081
# Epoch 81, CIFAR-10 Batch 5:
# Trainging cost at 0.8836567401885986
# Validation accuracy at 0.6441998481750488
# Epoch 82, CIFAR-10 Batch 1:
# Trainging cost at 0.919138491153717
# Validation accuracy at 0.6391999125480652
# Epoch 82, CIFAR-10 Batch 2:
# Trainging cost at 0.9424073696136475
# Validation accuracy at 0.6411998867988586
# Epoch 82, CIFAR-10 Batch 3:
# Trainging cost at 0.894332766532898
# Validation accuracy at 0.640799880027771
# Epoch 82, CIFAR-10 Batch 4:
# Trainging cost at 0.921789824962616
# Validation accuracy at 0.6383998394012451
# Epoch 82, CIFAR-10 Batch 5:
# Trainging cost at 0.881022572517395
# Validation accuracy at 0.6429999470710754
# Epoch 83, CIFAR-10 Batch 1:
# Trainging cost at 0.9172247648239136
# Validation accuracy at 0.6391998529434204
# Epoch 83, CIFAR-10 Batch 2:
# Trainging cost at 0.9391469359397888
# Validation accuracy at 0.6441999077796936
# Epoch 83, CIFAR-10 Batch 3:
# Trainging cost at 0.8913814425468445
# Validation accuracy at 0.6411998271942139
# Epoch 83, CIFAR-10 Batch 4:
# Trainging cost at 0.9184398651123047
# Validation accuracy at 0.6401998400688171
# Epoch 83, CIFAR-10 Batch 5:
# Trainging cost at 0.8767573833465576
# Validation accuracy at 0.6459999084472656
# Epoch 84, CIFAR-10 Batch 1:
# Trainging cost at 0.9160407185554504
# Validation accuracy at 0.6403998732566833
# Epoch 84, CIFAR-10 Batch 2:
# Trainging cost at 0.9377005100250244
# Validation accuracy at 0.6433998346328735
# Epoch 84, CIFAR-10 Batch 3:
# Trainging cost at 0.8878340125083923
# Validation accuracy at 0.6413998603820801
# Epoch 84, CIFAR-10 Batch 4:
# Trainging cost at 0.9184870719909668
# Validation accuracy at 0.6401998996734619
# Epoch 84, CIFAR-10 Batch 5:
# Trainging cost at 0.8747337460517883
# Validation accuracy at 0.6461998820304871
# Epoch 85, CIFAR-10 Batch 1:
# Trainging cost at 0.9118072390556335
# Validation accuracy at 0.6417998671531677
# Epoch 85, CIFAR-10 Batch 2:
# Trainging cost at 0.9356235265731812
# Validation accuracy at 0.6445999145507812
# Epoch 85, CIFAR-10 Batch 3:
# Trainging cost at 0.8850560784339905
# Validation accuracy at 0.6437998414039612
# Epoch 85, CIFAR-10 Batch 4:
# Trainging cost at 0.9178507924079895
# Validation accuracy at 0.6387998461723328
# Epoch 85, CIFAR-10 Batch 5:
# Trainging cost at 0.8718701601028442
# Validation accuracy at 0.6469998955726624
# Epoch 86, CIFAR-10 Batch 1:
# Trainging cost at 0.9071913361549377
# Validation accuracy at 0.6419999003410339
# Epoch 86, CIFAR-10 Batch 2:
# Trainging cost at 0.9351577162742615
# Validation accuracy at 0.642599880695343
# Epoch 86, CIFAR-10 Batch 3:
# Trainging cost at 0.8830450773239136
# Validation accuracy at 0.6433998942375183
# Epoch 86, CIFAR-10 Batch 4:
# Trainging cost at 0.9159961342811584
# Validation accuracy at 0.6393998861312866
# Epoch 86, CIFAR-10 Batch 5:
# Trainging cost at 0.8702738285064697
# Validation accuracy at 0.6467998623847961
# Epoch 87, CIFAR-10 Batch 1:
# Trainging cost at 0.905551016330719
# Validation accuracy at 0.6423999071121216
# Epoch 87, CIFAR-10 Batch 2:
# Trainging cost at 0.9337281584739685
# Validation accuracy at 0.6419999599456787
# Epoch 87, CIFAR-10 Batch 3:
# Trainging cost at 0.8807764053344727
# Validation accuracy at 0.6449998617172241
# Epoch 87, CIFAR-10 Batch 4:
# Trainging cost at 0.9149960875511169
# Validation accuracy at 0.6403998732566833
# Epoch 87, CIFAR-10 Batch 5:
# Trainging cost at 0.8690918684005737
# Validation accuracy at 0.6491998434066772
# Epoch 88, CIFAR-10 Batch 1:
# Trainging cost at 0.902787446975708
# Validation accuracy at 0.6429998874664307
# Epoch 88, CIFAR-10 Batch 2:
# Trainging cost at 0.9318212270736694
# Validation accuracy at 0.6405999064445496
# Epoch 88, CIFAR-10 Batch 3:
# Trainging cost at 0.8790332078933716
# Validation accuracy at 0.6447998881340027
# Epoch 88, CIFAR-10 Batch 4:
# Trainging cost at 0.9117872714996338
# Validation accuracy at 0.6399999260902405
# Epoch 88, CIFAR-10 Batch 5:
# Trainging cost at 0.8667914867401123
# Validation accuracy at 0.6497998833656311
# Epoch 89, CIFAR-10 Batch 1:
# Trainging cost at 0.8987134695053101
# Validation accuracy at 0.6453999280929565
# Epoch 89, CIFAR-10 Batch 2:
# Trainging cost at 0.9287006258964539
# Validation accuracy at 0.6421999335289001
# Epoch 89, CIFAR-10 Batch 3:
# Trainging cost at 0.877419114112854
# Validation accuracy at 0.64739990234375
# Epoch 89, CIFAR-10 Batch 4:
# Trainging cost at 0.9071710109710693
# Validation accuracy at 0.6411999464035034
# Epoch 89, CIFAR-10 Batch 5:
# Trainging cost at 0.8628417253494263
# Validation accuracy at 0.6511998176574707
# Epoch 90, CIFAR-10 Batch 1:
# Trainging cost at 0.8967301845550537
# Validation accuracy at 0.6477998495101929
# Epoch 90, CIFAR-10 Batch 2:
# Trainging cost at 0.9445638060569763
# Validation accuracy at 0.636199951171875
# Epoch 90, CIFAR-10 Batch 3:
# Trainging cost at 0.8856091499328613
# Validation accuracy at 0.6419999003410339
# Epoch 90, CIFAR-10 Batch 4:
# Trainging cost at 0.9035565853118896
# Validation accuracy at 0.643799901008606
# Epoch 90, CIFAR-10 Batch 5:
# Trainging cost at 0.8661127686500549
# Validation accuracy at 0.6465998888015747
# Epoch 91, CIFAR-10 Batch 1:
# Trainging cost at 0.9159283638000488
# Validation accuracy at 0.6413999795913696
# Epoch 91, CIFAR-10 Batch 2:
# Trainging cost at 0.9475284218788147
# Validation accuracy at 0.6365998983383179
# Epoch 91, CIFAR-10 Batch 3:
# Trainging cost at 0.8731441497802734
# Validation accuracy at 0.6411999464035034
# Epoch 91, CIFAR-10 Batch 4:
# Trainging cost at 0.9081910848617554
# Validation accuracy at 0.6409999132156372
# Epoch 91, CIFAR-10 Batch 5:
# Trainging cost at 0.8663761615753174
# Validation accuracy at 0.645599901676178
# Epoch 92, CIFAR-10 Batch 1:
# Trainging cost at 0.9176823496818542
# Validation accuracy at 0.6391998529434204
# Epoch 92, CIFAR-10 Batch 2:
# Trainging cost at 0.9258684515953064
# Validation accuracy at 0.6441999077796936
# Epoch 92, CIFAR-10 Batch 3:
# Trainging cost at 0.9053559303283691
# Validation accuracy at 0.6269998550415039
# Epoch 92, CIFAR-10 Batch 4:
# Trainging cost at 0.9016984105110168
# Validation accuracy at 0.6477999091148376
# Epoch 92, CIFAR-10 Batch 5:
# Trainging cost at 0.8773041367530823
# Validation accuracy at 0.6405999064445496
# Epoch 93, CIFAR-10 Batch 1:
# Trainging cost at 0.8856191635131836
# Validation accuracy at 0.644399881362915
# Epoch 93, CIFAR-10 Batch 2:
# Trainging cost at 0.9241524934768677
# Validation accuracy at 0.6417998671531677
# Epoch 93, CIFAR-10 Batch 3:
# Trainging cost at 0.8854334950447083
# Validation accuracy at 0.6391999125480652
# Epoch 93, CIFAR-10 Batch 4:
# Trainging cost at 0.9013903737068176
# Validation accuracy at 0.6479998826980591
# Epoch 93, CIFAR-10 Batch 5:
# Trainging cost at 0.8702244758605957
# Validation accuracy at 0.6435999274253845
# Epoch 94, CIFAR-10 Batch 1:
# Trainging cost at 0.886624813079834
# Validation accuracy at 0.6479998826980591
# Epoch 94, CIFAR-10 Batch 2:
# Trainging cost at 0.9289212822914124
# Validation accuracy at 0.6401998996734619
# Epoch 94, CIFAR-10 Batch 3:
# Trainging cost at 0.8869853019714355
# Validation accuracy at 0.6357998847961426
# Epoch 94, CIFAR-10 Batch 4:
# Trainging cost at 0.9008458852767944
# Validation accuracy at 0.6445998549461365
# Epoch 94, CIFAR-10 Batch 5:
# Trainging cost at 0.860368013381958
# Validation accuracy at 0.6457998752593994
# Epoch 95, CIFAR-10 Batch 1:
# Trainging cost at 0.8894096612930298
# Validation accuracy at 0.6439998745918274
# Epoch 95, CIFAR-10 Batch 2:
# Trainging cost at 0.9287253618240356
# Validation accuracy at 0.640799880027771
# Epoch 95, CIFAR-10 Batch 3:
# Trainging cost at 0.8730570077896118
# Validation accuracy at 0.6421998739242554
# Epoch 95, CIFAR-10 Batch 4:
# Trainging cost at 0.8982421159744263
# Validation accuracy at 0.6421998739242554
# Epoch 95, CIFAR-10 Batch 5:
# Trainging cost at 0.8529536724090576
# Validation accuracy at 0.6481999158859253
# Epoch 96, CIFAR-10 Batch 1:
# Trainging cost at 0.8877764940261841
# Validation accuracy at 0.6449998617172241
# Epoch 96, CIFAR-10 Batch 2:
# Trainging cost at 0.9254909753799438
# Validation accuracy at 0.640799880027771
# Epoch 96, CIFAR-10 Batch 3:
# Trainging cost at 0.865281879901886
# Validation accuracy at 0.643799901008606
# Epoch 96, CIFAR-10 Batch 4:
# Trainging cost at 0.8960579633712769
# Validation accuracy at 0.6427998542785645
# Epoch 96, CIFAR-10 Batch 5:
# Trainging cost at 0.8483720421791077
# Validation accuracy at 0.6485999226570129
# Epoch 97, CIFAR-10 Batch 1:
# Trainging cost at 0.8869953751564026
# Validation accuracy at 0.6463998556137085
# Epoch 97, CIFAR-10 Batch 2:
# Trainging cost at 0.9212526679039001
# Validation accuracy at 0.642599880695343
# Epoch 97, CIFAR-10 Batch 3:
# Trainging cost at 0.8644129037857056
# Validation accuracy at 0.6433999538421631
# Epoch 97, CIFAR-10 Batch 4:
# Trainging cost at 0.8954651951789856
# Validation accuracy at 0.6419998407363892
# Epoch 97, CIFAR-10 Batch 5:
# Trainging cost at 0.846977949142456
# Validation accuracy at 0.6481999158859253
# Epoch 98, CIFAR-10 Batch 1:
# Trainging cost at 0.8879245519638062
# Validation accuracy at 0.6459999084472656
# Epoch 98, CIFAR-10 Batch 2:
# Trainging cost at 0.9201937913894653
# Validation accuracy at 0.643799901008606
# Epoch 98, CIFAR-10 Batch 3:
# Trainging cost at 0.8630040884017944
# Validation accuracy at 0.6417999267578125
# Epoch 98, CIFAR-10 Batch 4:
# Trainging cost at 0.8989502191543579
# Validation accuracy at 0.6419998407363892
# Epoch 98, CIFAR-10 Batch 5:
# Trainging cost at 0.846554160118103
# Validation accuracy at 0.6485999226570129
# Epoch 99, CIFAR-10 Batch 1:
# Trainging cost at 0.8894373178482056
# Validation accuracy at 0.6455998420715332
# Epoch 99, CIFAR-10 Batch 2:
# Trainging cost at 0.9138873219490051
# Validation accuracy at 0.645599901676178
# Epoch 99, CIFAR-10 Batch 3:
# Trainging cost at 0.8658576011657715
# Validation accuracy at 0.642599880695343
# Epoch 99, CIFAR-10 Batch 4:
# Trainging cost at 0.8986476063728333
# Validation accuracy at 0.640799880027771
# Epoch 99, CIFAR-10 Batch 5:
# Trainging cost at 0.8538171052932739
# Validation accuracy at 0.6451998949050903
# Epoch 100, CIFAR-10 Batch 1:
# Trainging cost at 0.879652738571167
# Validation accuracy at 0.6455998420715332
# Epoch 100, CIFAR-10 Batch 2:
# Trainging cost at 0.9051341414451599
# Validation accuracy at 0.6461998820304871
# Epoch 100, CIFAR-10 Batch 3:
# Trainging cost at 0.8790610432624817
# Validation accuracy at 0.6373999118804932
# Epoch 100, CIFAR-10 Batch 4:
# Trainging cost at 0.9073300361633301
# Validation accuracy at 0.6413999199867249
# Epoch 100, CIFAR-10 Batch 5:
# Trainging cost at 0.8576515316963196
# Validation accuracy at 0.6439998745918274

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6405000030994416

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
